# %% [markdown]
# Section to Check If a image is fractured or not

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing import image


# Function to predict image class
def predict_fracture(image_path):
    img = image.load_img(image_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = loaded_model.predict(x)
    if preds[0][0] > 0.5:
        return "Non-Fractured"
    else:
        return "Fractured"

# Example usage
image_path = r"C:\Users\rog62\OneDrive\Documents\test\test\2207_0869206535_01_WRI-L1_F007.png"
predicted_class = predict_fracture(image_path)
print("Predicted Class:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step
# Predicted Class: Fractured

# %% [markdown]
# Predicted Number of Fractures and non_fractures

# %%
import os

# Directory containing the images
image_dir = r'C:\Users\rog62\OneDrive\Documents\test\test'

# Function to predict image class
def predict_fracture(image_path):
    # Your image prediction code here
    # Assuming you have the model loaded and the prediction function defined
    
# Initialize counts
fractured_count = 0
non_fractured_count = 0

# Iterate through the images in the directory
for filename in os.listdir(image_dir):
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        image_path = os.path.join(image_dir, filename)
        predicted_class = predict_fracture(image_path)
        if predicted_class == "Fractured":
            fractured_count += 1
        elif predicted_class == "Non-Fractured":
            non_fractured_count += 1

# Output counts
print("Number of Fractured Images:", fractured_count)
print("Number of Non-Fractured Images:", non_fractured_count)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 773ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 873ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 792ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 682ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# ...
